# %%
import google_search as gs
import pandas as pd

# %%
x = gs.Search()

# %%
x.web_search('Elephant')

# %%
x.result.shape
# Out:
# (97, 3)

# %%
x.result[:15]
# Out:
#                                                 Title  \
# 0   Elephant - Wikipediahttps://en.wikipedia.org/w...
# 1   elephant | Description, Habitat, Scientific Na...
# 2   Elephants - latest news, breaking stories and ...
# 3   Elephant | Species | WWFhttps://www.worldwildl...
# 4   The Elephant Corridor - Luxury hotel in Sigiri...
# 5   12 Memorable Facts About Elephants | Mental Fl...
# 6   Which Elephant is Which? | Saint Louis Zoohttp...
# 7   Elephant | Basic Facts About Elephants | Defen...
# 8   African Elephant | African Wildlife Foundation...
# 9   African elephants | WWFwwf.panda.org › Knowled...
# 10  The unique elephant brain | Earth | EarthSkyht...
# 11  The Elephant Listening Projectwww.birds.cornel...
# 12  Elephants, Rhinos & People Protect Wildlife | ...
# 13  BBC - Earth - Dwarf elephant beats up big riva...
# 14  Elephant Genome Project | Broad Institutehttps...
#
#                                                  Link  \
# ...

# %%
x.save()
# Out:
# Saved search results as "data/Elephant @2018_11_11_14_50.csv"

# %%
df = pd.read_csv('data/Elephant @2018_11_11_14_50.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 3 columns):
# Title          97 non-null object
# Link           97 non-null object
# Description    97 non-null object
# dtypes: object(3)
# memory usage: 2.4+ KB

# %%
df[:15]
# Out:
#                                                 Title  \
# 0   Elephant - Wikipediahttps://en.wikipedia.org/w...
# 1   elephant | Description, Habitat, Scientific Na...
# 2   Elephants - latest news, breaking stories and ...
# 3   Elephant | Species | WWFhttps://www.worldwildl...
# 4   The Elephant Corridor - Luxury hotel in Sigiri...
# 5   12 Memorable Facts About Elephants | Mental Fl...
# 6   Which Elephant is Which? | Saint Louis Zoohttp...
# 7   Elephant | Basic Facts About Elephants | Defen...
# 8   African Elephant | African Wildlife Foundation...
# 9   African elephants | WWFwwf.panda.org › Knowled...
# 10  The unique elephant brain | Earth | EarthSkyht...
# 11  The Elephant Listening Projectwww.birds.cornel...
# 12  Elephants, Rhinos & People Protect Wildlife | ...
# 13  BBC - Earth - Dwarf elephant beats up big riva...
# 14  Elephant Genome Project | Broad Institutehttps...
#
#                                                  Link  \
# ...
