# %%
import google_search as gs
import pandas as pd

# %%
x = gs.Search()

# %%
x.image_search('Dog')

# %%
x.result.shape
# Out:
# (100, 7)

# %%
x.result[:15]
# Out:
#                                           description  \
# 0   What is 'trancing' and why does it make my dog...
# 1                               Dogs | Know Your Meme
# 2                                      Dogs & Puppies
# 3                             Akita (dog) - Wikipedia
# 4   Dog receives kidney donation from one of her p...
# 5                             Pets | American Apparel
# 6         Beauceball — Dog Tales Rescue and Sanctuary
# 7   Dog Insurance | Nationwide Dog and Puppy Insur...
# 8   Abused Dog Rescued with Shoelace Tied Around H...
# 9   Would Your Dog Eat You if You Died? Get the Fa...
# 10  25+ Photos Of Dogs Before & After Their Adopti...
# 11                           Adopt a dog | Blue Cross
# 12  Chinese New Year: Meet the cutest dogs of Inst...
# 13  Big Dog Names - Over 350 Awesome Ideas For Lar...
# 14  Who's a good boy? Why 'dog-speak' is important...
#
#                                              img_link type  height  width  \
# ...

# %%
x.save()
# Out:
# Saved search results as "data/Dog @2018_11_11_14_52.csv"
